# %%
import pickle

f = open(f"/Users/akotamraju/Documents/dev/URAP/main-responseapprox/data/fixed-massive-full-sim-data/TestSource.1.inc1.id1.tra.gz.pkl", "rb");
    
vals = pickle.load(f)

# %%
import numpy as np
vals = np.array(vals)
# Out:
# /Users/akotamraju/opt/anaconda3/envs/nn_response/lib/python3.7/site-packages/ipykernel_launcher.py:2: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.

# %%
import matplotlib.pyplot as plt
vals.shape
# Out:
# (7,)

# %%
plt.hist(vals[5])
plt.show()
