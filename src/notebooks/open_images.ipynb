# %%
import numpy as np

FILENAME="/Users/akotamraju/Documents/dev/URAP/main-responseapprox/logs/saved-images/lunar-gorge-147/180.npy"

arr = np.load(FILENAME)

# %%
print(arr.shape)
print(np.max(arr))
# Out:
# (36, 768, 1024)
# 534.17

# %%
NSIDE = 32
NUMPIX = 12 * NSIDE ** 2
COMPTON_RESOLUTION_DEG = 5

# %%
import healpy as hp
import matplotlib.pyplot as plt
import pickle

import sys

sys.path.append("../utils")

from mapping import reconstruct_from_cartesian

with open(f'/Users/akotamraju/Documents/dev/URAP/main-responseapprox/mappings/NSIDE_128_x1024_y768.pkl', 'rb') as f:
    cart_to_heal_map = pickle.load(f)

for i in range(36):
    test_data_y = arr[i]

    # flat = test_data_y.flatten()

    recons = reconstruct_from_cartesian(test_data_y, 128, cart_to_heal_map)


    # minval = np.min(cross_sec[np.nonzero(cross_sec)])
    # maxval = np.max(cross_sec[np.nonzero(cross_sec)])

    # print(minval, maxval)

    hp.mollview(recons)
# Out:
# /Users/akotamraju/opt/anaconda3/envs/nn_response/lib/python3.7/site-packages/healpy/visufunc.py:200: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   f = pylab.figure(fig, figsize=(8.5, 5.4))
