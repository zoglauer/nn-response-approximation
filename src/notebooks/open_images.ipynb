# %%
import numpy as np

FILENAME="../../logs/saved-images/auspicious-rat-16/110-truth.npy"

arr = np.load(FILENAME)

# %%
print(arr.shape)
print(np.max(arr))
# Out:
# (18, 96, 128)
# 121.73273

# %%
NSIDE = 16
NUMPIX = 12 * NSIDE ** 2
COMPTON_RESOLUTION_DEG = 10

# %%
import healpy as hp
import matplotlib.pyplot as plt
import pickle

import sys

sys.path.append("../utils")

from mapping import reconstruct_from_cartesian

with open(f'/Users/akotamraju/Documents/dev/URAP/main-responseapprox/mappings/NSIDE_16_x128_y96.pkl', 'rb') as f:
    cart_to_heal_map = pickle.load(f)

for i in range(len(arr)):
    test_data_y = np.array(arr[i])

    # print(test_data_y[])
    

    # ignoring the max value 
    max_removed = np.where(test_data_y!=np.max(test_data_y),test_data_y, 0)
    #ignoring second max
    max_removed = np.where(max_removed!=np.max(max_removed),max_removed, 0)

    # flat = test_data_y.flatten()

    recons = reconstruct_from_cartesian(max_removed, NSIDE, cart_to_heal_map)



    # minval = np.min(cross_sec[np.nonzero(cross_sec)])
    # maxval = np.max(cross_sec[np.nonzero(cross_sec)])

    # print(minval, maxval)

    hp.mollview(recons)
