# %%
import sys

# Move to scripts directory
sys.path.append('../scripts')

import pickle
import numpy as np
from create_cross_sec import create_cross_sec

f = open(f"/Users/akotamraju/Documents/dev/URAP/main-responseapprox/data/full-sim-data/FlatContinuumIsotropic.inc508.id1.tra.gz.pkl", "rb");
    
vals = pickle.load(f)

full_sim_data = np.array(vals)
print(full_sim_data.shape)

cross_sec = create_cross_sec(full_sim_data, 64, 64 ** 2 * 12, 5)
# Out:
# /Users/akotamraju/opt/anaconda3/envs/nn_response/lib/python3.7/site-packages/ipykernel_launcher.py:14: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
# (7,)
# ---> 0 values loaded
# ---> 100000 values loaded
# ---> 200000 values loaded
# ---> 300000 values loaded
# ---> 400000 values loaded
# ---> 500000 values loaded
# ---> All values loaded.

# %%
DEPTH = 25
arr = cross_sec['y'][DEPTH]

import healpy as hp

hp.mollview(arr)

# %%
import matplotlib.pyplot as plt

plt.imshow(arr.reshape(192, 256))
