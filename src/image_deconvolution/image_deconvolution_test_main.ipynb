# %% [markdown]
# # Image Deconvolution
# - ver.0.0.2
# - 2023 May 4
# - H. Yoneda
#
# - Adapted Spring 2024 by E. Shread

# %%
import astropy.units as u
from astropy.time import Time

import matplotlib.pyplot as plt
import numpy as np

from mhealpy import HealpixMap
from scoords import SpacecraftFrame, Attitude
from cosipy.data_io import DataIO
from cosipy.image_deconvolution import DataLoader
from cosipy.image_deconvolution import ImageDeconvolution

import warnings
warnings.simplefilter("once")
# Out:
# 15:40:58 WARNING   The naima package is not available. Models that depend on it will not be         ]8;id=569264;file:///home/eshread/.local/lib/python3.10/site-packages/astromodels/functions/functions_1D/functions.py\functions.py]8;;\:]8;id=650820;file:///home/eshread/.local/lib/python3.10/site-packages/astromodels/functions/functions_1D/functions.py#48\48]8;;\
#                   available
#          WARNING   The GSL library or the pygsl wrapper cannot be loaded. Models that depend on it  ]8;id=845031;file:///home/eshread/.local/lib/python3.10/site-packages/astromodels/functions/functions_1D/functions.py\functions.py]8;;\:]8;id=144953;file:///home/eshread/.local/lib/python3.10/site-packages/astromodels/functions/functions_1D/functions.py#69\69]8;;\
#                   will not be available.
# /home/eshread/.local/lib/python3.10/site-packages/numba/core/decorators.py:262: NumbaDeprecationWarning: numba.generated_jit is deprecated. Please see the documentation at: https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-generated-jit for more information and advice on a suitable replacement.
#   warnings.warn(msg, NumbaDeprecationWarning)
#          WARNING   The ebltable package is not available. Models that depend on it will not be     ]8;id=990018;file:///home/eshread/.local/lib/python3.10/site-packages/astromodels/functions/functions_1D/absorption.py\absorption.py]8;;\:]8;id=783852;file:///home/eshread/.local/lib/python3.10/site-packages/astromodels/functions/functions_1D/absorption.py#36\36]8;;\
#                   available
#          WARNING   We have set the min_value of K to 1e-99 because there was a postive transform   ]8;id=962948;file:///home/eshread/.local/lib/python3.10/site-packages/astromodels/core/parameter.py\parameter.py]8;;\:]8;id=901546;file:///home/eshread/.local/lib/python3.10/site-packages/astromodels/core/parameter.py#704\704]8;;\
#          WARNING   We have set the min_value of K to 1e-99 because there was a postive transform   ]8;id=210720;file:///home/eshread/.local/lib/python3.10/site-packages/astromodels/core/parameter.py\parameter.py]8;;\:]8;id=751169;file:///home/eshread/.local/lib/python3.10/site-packages/astromodels/core/parameter.py#704\704]8;;\
#          WARNING   We have set the min_value of K to 1e-99 because there was a postive transform   ]8;id=603471;file:///home/eshread/.local/lib/python3.10/site-packages/astromodels/core/parameter.py\parameter.py]8;;\:]8;id=33620;file:///home/eshread/.local/lib/python3.10/site-packages/astromodels/core/parameter.py#704\704]8;;\
#          WARNING   We have set the min_value of K to 1e-99 because there was a postive transform   ]8;id=404670;file:///home/eshread/.local/lib/python3.10/site-packages/astromodels/core/parameter.py\parameter.py]8;;\:]8;id=998915;file:///home/eshread/.local/lib/python3.10/site-packages/astromodels/core/parameter.py#704\704]8;;\
#          WARNING   We have set the min_value of F to 1e-99 because there was a postive transform   ]8;id=250579;file:///home/eshread/.local/lib/python3.10/site-packages/astromodels/core/parameter.py\parameter.py]8;;\:]8;id=369085;file:///home/eshread/.local/lib/python3.10/site-packages/astromodels/core/parameter.py#704\704]8;;\
#          WARNING   We have set the min_value of K to 1e-99 because there was a postive transform   ]8;id=376680;file:///home/eshread/.local/lib/python3.10/site-packages/astromodels/core/parameter.py\parameter.py]8;;\:]8;id=436982;file:///home/eshread/.local/lib/python3.10/site-packages/astromodels/core/parameter.py#704\704]8;;\
# /home/eshread/.local/lib/python3.10/site-packages/numba/core/decorators.py:262: NumbaDeprecationWarning: numba.generated_jit is deprecated. Please see the documentation at: https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-generated-jit for more information and advice on a suitable replacement.
#   warnings.warn(msg, NumbaDeprecationWarning)
# 15:40:59 INFO      Starting 3ML!                                                                     ]8;id=974579;file:///home/eshread/.local/lib/python3.10/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=96938;file:///home/eshread/.local/lib/python3.10/site-packages/threeML/__init__.py#35\35]8;;\
#          WARNING   WARNINGs here are NOT errors                                                      ]8;id=62431;file:///home/eshread/.local/lib/python3.10/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=889156;file:///home/eshread/.local/lib/python3.10/site-packages/threeML/__init__.py#36\36]8;;\
#          WARNING   but are inform you about optional packages that can be installed                  ]8;id=407703;file:///home/eshread/.local/lib/python3.10/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=126449;file:///home/eshread/.local/lib/python3.10/site-packages/threeML/__init__.py#37\37]8;;\
#          WARNING    to disable these messages, turn off start_warning in your config file            ]8;id=613524;file:///home/eshread/.local/lib/python3.10/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=307263;file:///home/eshread/.local/lib/python3.10/site-packages/threeML/__init__.py#40\40]8;;\
#          WARNING   ROOT minimizer not available                                                ]8;id=380406;file:///home/eshread/.local/lib/python3.10/site-packages/threeML/minimizer/minimization.py\minimization.py]8;;\:]8;id=120411;file:///home/eshread/.local/lib/python3.10/site-packages/threeML/minimizer/minimization.py#1345\1345]8;;\
#          WARNING   Multinest minimizer not available                                           ]8;id=671143;file:///home/eshread/.local/lib/python3.10/site-packages/threeML/minimizer/minimization.py\minimization.py]8;;\:]8;id=110214;file:///home/eshread/.local/lib/python3.10/site-packages/threeML/minimizer/minimization.py#1357\1357]8;;\
#          WARNING   PyGMO is not available                                                      ]8;id=188454;file:///home/eshread/.local/lib/python3.10/site-packages/threeML/minimizer/minimization.py\minimization.py]8;;\:]8;id=363606;file:///home/eshread/.local/lib/python3.10/site-packages/threeML/minimizer/minimization.py#1369\1369]8;;\
# 15:40:59 WARNING   The cthreeML package is not installed. You will not be able to use plugins which  ]8;id=880777;file:///home/eshread/.local/lib/python3.10/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=325997;file:///home/eshread/.local/lib/python3.10/site-packages/threeML/__init__.py#94\94]8;;\
#                   require the C/C++ interface (currently HAWC)
#          WARNING   Could not import plugin HAWCLike.py. Do you have the relative instrument         ]8;id=571156;file:///home/eshread/.local/lib/python3.10/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=349300;file:///home/eshread/.local/lib/python3.10/site-packages/threeML/__init__.py#144\144]8;;\
#                   software installed and configured?
#          WARNING   Could not import plugin FermiLATLike.py. Do you have the relative instrument     ]8;id=970802;file:///home/eshread/.local/lib/python3.10/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=468042;file:///home/eshread/.local/lib/python3.10/site-packages/threeML/__init__.py#144\144]8;;\
#                   software installed and configured?
#          WARNING   No fermitools installed                                              ]8;id=443457;file:///home/eshread/.local/lib/python3.10/site-packages/threeML/utils/data_builders/fermi/lat_transient_builder.py\lat_transient_builder.py]8;;\:]8;id=146420;file:///home/eshread/.local/lib/python3.10/site-packages/threeML/utils/data_builders/fermi/lat_transient_builder.py#44\44]8;;\
#          WARNING   Env. variable OMP_NUM_THREADS is not set. Please set it to 1 for optimal         ]8;id=918598;file:///home/eshread/.local/lib/python3.10/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=51912;file:///home/eshread/.local/lib/python3.10/site-packages/threeML/__init__.py#387\387]8;;\
#                   performances in 3ML
#          WARNING   Env. variable MKL_NUM_THREADS is not set. Please set it to 1 for optimal         ]8;id=308007;file:///home/eshread/.local/lib/python3.10/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=224088;file:///home/eshread/.local/lib/python3.10/site-packages/threeML/__init__.py#387\387]8;;\
#                   performances in 3ML
#          WARNING   Env. variable NUMEXPR_NUM_THREADS is not set. Please set it to 1 for optimal     ]8;id=139939;file:///home/eshread/.local/lib/python3.10/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=566291;file:///home/eshread/.local/lib/python3.10/site-packages/threeML/__init__.py#387\387]8;;\
#                   performances in 3ML

# %%
event_tra_filepath = '/home/eshread/nn-response-approximation/TestSource.520.inc1.id1.tra.gz'

event_yaml_filepath = '/home/eshread/nn-response-approximation/tra_events.yaml' 

response_filepath = '' #put full detector response file here

# %% [markdown]
# ## load files
#
# - Need the dataIO library for the event and response files - in particular, UnbinnedData, BinnedData, and DataLoader
# - As of current (April 2024), the below cell only loads in the tra event data, bins it, and outputs both an unbinned and binned hdf5 file corresponding to the input tra file.
# - Not written into the code yet is iterating over multiple tra files. This can be a last step after incorporating the detector response.
# - Once the full detector response is obtained, you can edit the data loader class accordingly to also load the response from file.
# - Sure to run into memory allocation errors - it'll be best to run this in thebe.
# - To run only a subset of events, edit the event_min and event_max values inside UnbinnedData.read_tra()

# %%
dataloader = DataLoader.load_from_filepath(event_tra_filepath = event_tra_filepath, 
                                           event_yaml_filepath = event_yaml_filepath, 
                                           rsp_filepath = None)
# Out:
# ... loading event data from /home/eshread/nn-response-approximation/TestSource.520.inc1.id1.tra.gz
# Preparing to read file...
# Reading file...
#   0%|                                                                           | 0/132254619.0 [00:00<?, ?it/s]
# WARNING RuntimeWarning: invalid value encountered in arccos
#
#   0%|                                                           | 13213/132254619.0 [00:00<04:28, 492655.76it/s]
# Stopping here: only reading a subset of events
# Making COSI data set...
# Saving file...
# binning data...
# WARNING DeprecationWarning: coords should be an ndarray. This will raise a ValueError in the future.
#
#
# WARNING DeprecationWarning: coords should be an ndarray. This will raise a ValueError in the future.
#
#
# WARNING DeprecationWarning: coords should be an ndarray. This will raise a ValueError in the future.
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 dataloader = DataLoader.load_from_filepath(event_tra_filepath = event_tra_filepath,
#       2                                            event_yaml_filepath = event_yaml_filepath,
#       3                                            rsp_filepath = None)
#
# File ~/cosipy/cosipy/image_deconvolution/data_loader.py:54, in DataLoader.load_from_filepath(cls, event_tra_filepath, event_yaml_filepath, rsp_filepath)
#      49 @classmethod
#      50 def load_from_filepath(cls, event_tra_filepath = None, event_yaml_filepath = None, rsp_filepath = None):
#      52     new = cls()
# ---> 54     new.set_event_from_filepath(event_tra_filepath, event_yaml_filepath)
#      55     #new.set_rsp_from_filepath(rsp_filepath) #this is commented out until we have full detector response
#      57     return new
#
# File ~/cosipy/cosipy/image_deconvolution/data_loader.py:92, in DataLoader.set_event_from_filepath(self, tra_filepath, yaml_filepath)
#      88 self._event_binned_hdf5_filepath = binned_hdf5_filepath
#      90 event_binned.load_binned_data_from_hdf5(self._event_binned_hdf5_filepath)
# ---> 92 self.event_dense = event_binned.binned_data.to_dense()
#      93 self.event_sparse = event_binned.binned_data.to_sparse()
#      94 print("... Done ...")
#
# File ~/.local/lib/python3.10/site-packages/histpy/histogram.py:254, in Histogram.to_dense(self)
#     251 h_dense = deepcopy(self)
#     253 if h_dense.is_sparse:
# --> 254     h_dense._contents = self.full_contents.todense()
#     256 if h_dense._sumw2 is not None:
#     257     h_dense._sumw2 = h_dense._sumw2.to_dense()
#
# File ~/.local/lib/python3.10/site-packages/sparse/_coo/core.py:434, in COO.todense(self)
#     410 def todense(self):
#     411     """
#     412     Convert this :obj:`COO` array to a dense :obj:`numpy.ndarray`. Note that
#     413     this may take a large amount of memory if the :obj:`COO` object's :code:`shape`
#    (...)
#     432     True
#     433     """
# --> 434     x = np.full(self.shape, self.fill_value, self.dtype)
#     436     coords = tuple([self.coords[i, :] for i in range(self.ndim)])
#     437     data = self.data
#
# File ~/.local/lib/python3.10/site-packages/numpy/core/numeric.py:329, in full(shape, fill_value, dtype, order, like)
#     327     fill_value = asarray(fill_value)
#     328     dtype = fill_value.dtype
# --> 329 a = empty(shape, dtype, order)
#     330 multiarray.copyto(a, fill_value, casting='unsafe')
#     331 return a
#
# MemoryError: Unable to allocate 633. GiB for an array with shape (7202, 3, 20, 196610) and data type float64

# %%
import pickle

f=open(response_filepath, 'rb')
data_dict = np.array(pickle.load(f))
print(data_dict.shape)
f.close()

# %% [markdown]
# ## load data

# %%
image_deconvolution = ImageDeconvolution()

# %%
image_deconvolution.set_data(dataloader)

# %% [markdown]
# ## load parameterfile

# %%
parameter_filepath = "/home/eshread/nn-response-approximation/parameter_file.yaml"

image_deconvolution.read_parameterfile(parameter_filepath)

# %% [markdown]
# ## sparse matrix?

# %%
image_deconvolution.use_sparse = False

# %% [markdown]
# ## initialization
# - produce an initial flux map etc.

# %%
image_deconvolution.initialize()

# %% [markdown]
# ## change the parameter
# - change the iteration from 10 to 20
# - you should run "initialize" after parameters are changed

# %%
print(image_deconvolution.parameter.dump())

# %%
image_deconvolution.override_parameter("deconvolution:parameter_RL:iteration = 20")

# %%
print(image_deconvolution.parameter.dump())

# %%
image_deconvolution.initialize()

# %% [markdown]
# ## run deconvolution

# %%
# %%time

all_result = image_deconvolution.run_deconvolution()

# %% [markdown]
# ## analyze the result

# %%
print(all_result)

# %% [markdown]
# ### likelihood

# %%
x, y = [], []

for _ in all_result:
    x.append(_['iteration'])
    y.append(_['loglikelihood'])
    
plt.plot(x, y)
plt.xlabel("iteration")
plt.ylabel("loglikelihood")

# %% [markdown]
# ### alpha

# %%
x, y = [], []

for _ in all_result:
    x.append(_['iteration'])
    y.append(_['alpha'])
    
plt.plot(x, y)
plt.xlabel("iteration")
plt.ylabel("alpha")

# %% [markdown]
# ### image

# %%
for _ in all_result:
    iteration = _['iteration']
    image = _['model_map']
        
    for energy_band in range(5):
        map_healpxmap = HealpixMap(data = image[:,energy_band], unit = image.unit)

        map_healpxmap.plot()
        plt.title(label = "iteration = {}, energyband = {}".format(iteration, energy_band))
        plt.show()

# %% [markdown]
# ### delta_image

# %%
for _ in all_result:
    iteration = _['iteration']
    image = _['delta_map']
        
    for energy_band in range(5):
        map_healpxmap = HealpixMap(data = image[:,energy_band], unit = image.unit)

        map_healpxmap.plot()
        plt.title(label = "iteration = {}, energyband = {}".format(iteration, energy_band))
        plt.show()

# %% [markdown]
# ### flux

# %%
iteration = []
integrated_flux = []
integrated_flux_each_band = [[],[],[],[],[]]

for _ in all_result:
    iteration.append(_['iteration'])
    image = _['model_map']

    integrated_flux.append( np.sum(image) / image.unit)

    for energy_band in range(5):
        integrated_flux_each_band[energy_band].append( np.sum(image[:,energy_band]) / image.unit)
        
plt.plot(iteration, integrated_flux, label = 'total')
plt.xlabel("iteration")
plt.ylabel("integrated flux")
plt.yscale("log")

for energy_band in range(5):
    plt.plot(iteration, integrated_flux_each_band[energy_band], label = "energyband = {}".format(energy_band))
    
plt.legend()

# %% [markdown]
# ### flux delta

# %%
iteration = []
delta_integrated_flux = []
delta_integrated_flux_each_band = [[],[],[],[],[]]

for _ in all_result:
    iteration.append(_['iteration'])
    delta_image = _['delta_map']

    delta_integrated_flux.append( np.sum(delta_image) / delta_image.unit)

    for energy_band in range(5):
        delta_integrated_flux_each_band[energy_band].append( np.sum(delta_image[:,energy_band]) / delta_image.unit)
        
plt.plot(iteration, delta_integrated_flux, label = 'total')
plt.xlabel("iteration")
plt.ylabel("delta integrated flux")
plt.ylim(-0.08, 0.08)

for energy_band in range(5):
    plt.plot(iteration, delta_integrated_flux_each_band[energy_band], label = "energyband = {}".format(energy_band))
    
plt.legend()

# %% [markdown]
# ## comparision with the truth value

# %%
from astromodels import Powerlaw
from scipy import integrate
from astropy.units import Quantity

spectrum = Powerlaw(K = 1e-1, index = -1.7)

integrated_flux_truth = integrate.quad(spectrum, 100, 5000.0)[0] / u.cm**2 / u.s
pixel_area = 4 * 3.1415 * u.sr / all_result[0]['model_map'].axes['NuLambda'].npix

print("truth:", integrated_flux_truth)

print("deconvolution:", integrated_flux[-1] * pixel_area * u.cm**-2 * u.s**-1 * u.sr**-1)

# %%
integrated_flux_each_band_truth = []

for energy_band in range(5):
    emin, emax = dataloader.response.axes["Ei"].bounds[energy_band]

    integrated_flux_each_band_truth.append(integrate.quad(spectrum, emin.value, emax.value)[0] / u.cm**2 / u.s)
    pixel_area = 4 * 3.1415 * u.sr / all_result[0]['model_map'].axes['NuLambda'].npix
    
    print(emin, emax)
    print("    truth:", integrated_flux_each_band_truth[energy_band])
    print("    deconvolution:", integrated_flux_each_band[energy_band][-1] * pixel_area * u.cm**-2 * u.s**-1 * u.sr**-1)

# %%
iteration = []
integrated_flux = []
integrated_flux_each_band = [[],[],[],[],[]]

for _ in all_result:
    iteration.append(_['iteration'])
    image = _['model_map']

    integrated_flux.append( np.sum(image) / image.unit)

    for energy_band in range(5):
        integrated_flux_each_band[energy_band].append( np.sum(image[:,energy_band]) / image.unit)
        
plt.plot(iteration, integrated_flux * pixel_area, label = 'total', color = 'black')
plt.plot(iteration, np.full(len(iteration), integrated_flux_truth), color = 'black', linestyle = "--")
plt.xlabel("iteration")
plt.ylabel("integrated flux")
plt.yscale("log")


colors = ['b', 'g', 'r', 'c', 'm']
for energy_band in range(5):
    plt.plot(iteration, integrated_flux_each_band[energy_band] * pixel_area, label = "energyband = {}".format(energy_band), color = colors[energy_band])
    plt.plot(iteration, np.full(len(iteration), integrated_flux_each_band_truth[energy_band]), color = colors[energy_band], linestyle = "--")
    
plt.legend()
